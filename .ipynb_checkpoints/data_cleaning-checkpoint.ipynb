# %% [markdown]
# ### Importing Dependencies

# %%
import pandas as pd
import os
import requests
import json
# from config import password
from sqlalchemy import create_engine

# %% [markdown]
# ### Creating a function to import csv data from multiple countries

# %%
def import_func(country_code):
    
    #Creating Path
    
    path = os.path.join('data',f'{country_code}_youtube_trending_data.csv')
    
    
    #Storing dataframe to df
    
    df=pd.read_csv(path)
    
    #Removing unwanted columns below
    
    df=df[['video_id','title','publishedAt','channelTitle','categoryId','trending_date','view_count','likes','dislikes','comment_count','thumbnail_link']]
    
    
    #Changing object types to date types for two columns
    
    df['publishedAt']=pd.to_datetime(df['publishedAt'])
    df['trending_date']=pd.to_datetime(df['trending_date'])
    
    
    #Removing time stamp from date
    
    df['publishedAt']=df['publishedAt'].dt.date 
    df['trending_date']=df['trending_date'].dt.date
    
    
    with open(f'data/{country_code}_category_id.json', 'r') as read_file:
        category_ids = json.load(read_file)

        df=df.astype({'categoryId': 'str'})
        
    for index,row in df.iterrows():
    
        for entry in category_ids["items"]:

            if row["categoryId"]==entry["id"]:
                df.at[index,"categoryId"]=entry["snippet"]["title"]
    
    #Adding country Code as column
    df['country']=f'{country_code}'
    col_name='country'
    
    
    #Moving country code to first column
    first_col = df.pop(col_name)
    df.insert(0,col_name,first_col)
    
    return df

# %% [markdown]
# ### Creating all dataframes using import function

# %%
#USA Dataframe
df_us=import_func('US')

#Brasil Dataframe
df_br=import_func('BR')

#Canada Dataframe
df_ca=import_func('CA')

#Mexico Dataframe
df_mx=import_func('MX')

# %% [markdown]
# ### Combining all data to one dataframe

# %%
#Creating a varible to add all dfs
country_df=[df_us,df_br,df_ca,df_mx]

df_main = pd.concat(country_df)
df_main
# Out:
#       country     video_id                                              title  \
# 0          US  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1          US  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2          US  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3          US  kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4          US  VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
# ...       ...          ...                                                ...
# 21795      MX  -qg-hVGJiic                        KAI 카이 '음 (Mmmh)' MV Teaser
# 21796      MX  b8p1VkdnLtA  Entrevista con Ernesto Cazares, el eliminado d...
# 21797      MX  S6dv0YvFeak    MI PAPÁ RESPONDE PREGUNTAS INCOMODAS XIME PONCH
# 21798      MX  Rz3I0souiEw          BTS (방탄소년단) 'Dynamite' @ Best Artist 2020
# 21799      MX  jr764STQE-M  Delineadores de Yuya vs. Los del Mercado ¿Está...
#
#       publishedAt   channelTitle      categoryId trending_date  view_count  \
# 0      2020-08-11       Brawadis  People & Blogs    2020-08-12     1514614
# 1      2020-08-11   Apex Legends          Gaming    2020-08-12     2381688
# 2      2020-08-11  jacksepticeye   Entertainment    2020-08-12     2038853
# 3      2020-08-11            XXL           Music    2020-08-12      496771
# 4      2020-08-11       Mr. Kate   Howto & Style    2020-08-12     1123889
# ...           ...            ...             ...           ...         ...
# 21795  2020-11-26         SMTOWN           Music    2020-12-01     3197726
# 21796  2020-11-24      TV Azteca   Entertainment    2020-12-01       79963
# 21797  2020-11-24     Xime Ponch  People & Blogs    2020-12-01      366384
# 21798  2020-11-25      BANGTANTV           Music    2020-12-01     7839236
# 21799  2020-11-23   Anna Sarelly   Howto & Style    2020-12-01      470233
#
#          likes  dislikes  comment_count  \
# 0       156908      5855          35313
# 1       146739      2794          16549
# 2       353787      2628          40221
# 3        23251      1856           7647
# 4        45802       964           2196
# ...        ...       ...            ...
# 21795   591263      4442          75964
# 21796     1550        90            281
# 21797    31512       355            951
# 21798  1451772      4553          65222
# 21799    35553       750           1822
#
#                                        thumbnail_link
# 0      https://i.ytimg.com/vi/3C66w5Z0ixs/default.jpg
# 1      https://i.ytimg.com/vi/M9Pmf9AB4Mo/default.jpg
# 2      https://i.ytimg.com/vi/J78aPJ3VyNs/default.jpg
# 3      https://i.ytimg.com/vi/kXLn3HkpjaA/default.jpg
# 4      https://i.ytimg.com/vi/VIUo6yapDbc/default.jpg
# ...                                               ...
# 21795  https://i.ytimg.com/vi/-qg-hVGJiic/default.jpg
# 21796  https://i.ytimg.com/vi/b8p1VkdnLtA/default.jpg
# 21797  https://i.ytimg.com/vi/S6dv0YvFeak/default.jpg
# 21798  https://i.ytimg.com/vi/Rz3I0souiEw/default.jpg
# 21799  https://i.ytimg.com/vi/jr764STQE-M/default.jpg
#
# [87791 rows x 12 columns]

# %% [markdown]
# ### ADDED TODAY

# %% [markdown]
# ### Creating a function to get popular statistics

# %%
def stats(country_code):
    
    #Invoiking import_func to capture all the date based on country

    df=import_func(f'{country_code}')
    

    #Grouping dataframe by category to get all likes
    
    df_likes=df.groupby('categoryId').likes.sum()
    
    
    #Grouping dataframe by category to get all dislikes
    
    df_dislikes=df.groupby('categoryId').dislikes.sum()
    
    
    ##Grouping dataframe by category to get total view count
    
    df_view_count=df.groupby('categoryId').view_count.sum()
   
   
    return df_likes.reset_index(),df_dislikes.reset_index(),df_view_count.reset_index()

# %%
#Example


df_US_likes,df_US_dislikes,df_US_view_count=stats('US')

# %% [markdown]
# ### Creating SQL engine to connnect to Postgres

# %%
# # #Connect to Database

# # pg_user = 'postgres'
# # pg_password=password
# # db_name = 'youtube_database'
# # connection_string = f'{pg_user}:{password}@localhost:5432/{db_name}'
# # engine=create_engine(f'postgresql://{connection_string}')

# #Connect to Database - Alternative
# dbuser = 'postgres'
# dbpassword = 'Sm6Jc5bqbiNQdsVAo7eN'
# dbhost = 'localhost'
# dbport = '5432'
# dbname= 'youtube_database'
# connection_string2 = f'{dbuser}:{dbpassword}@database-1.cvmfiiilpm7y.us-east-1.rds.amazonaws.com:{dbport}/{dbname}'
# engine=create_engine(f'postgresql://{connection_string2}')

# %%
# engine.table_names()
# Out:
# []

# %%
# df_main.to_sql(name='youtube_table',con=engine,if_exists='append',index=False)

# %% [markdown]
# #### For App.py routes

# %%
from datetime import datetime

# Routes to fill the drop down menus
# Dropdown menu#1
youtubeVids = df_main
country_df = youtubeVids['country'].value_counts() 
countryList = country_df.index.tolist()
countryList

# Dropdown menu#2
youtubeVids = df_main
youtubeVids['categoryId'] = youtubeVids['categoryId'].replace(["29"],"Nonprofits & Activism")
category_df = df_main['categoryId'].value_counts() 
categoryList = category_df.index.tolist()
categoryList

# Dropdown menu#3
metricList = ['Views', 'Likes', 'Dislikes', 'Comments']

# %%
df_main = df_main.rename(columns={'country': 'country', 'video_id': 'video_id', 'title': 'title', 'publishedAt': 'publishedAt', 'channelTitle': 'channelTitle', 'categoryId': 'categoryId',
                                  'trending_date': 'trending_date', 'view_count': 'views', 'likes': 'likes', 'dislikes': 'dislikes', 'comment_count': 'comments', 'thumbnail_link': 'thumbnail_link'})

# %%
# CREATING A HEROKU DATASET
# Heroku only takes data with <10k rows so I created a heroku dataset (incase we ever want to host on heroku).

def import_func(country_code):
    
    #Creating Path
    path = os.path.join('data',f'{country_code}_youtube_trending_data.csv')
    
    
    #Storing dataframe to df
    dfh=pd.read_csv(path)
    
    #Removing unwanted columns below
    dfh=dfh[['video_id','title','publishedAt','channelTitle','categoryId','trending_date','view_count','likes','dislikes','comment_count','thumbnail_link']]
    
    #Renaming columns
    dfh = dfh.rename(columns={'view_count': 'views', 'likes': 'likes', 'dislikes': 'dislikes', 'comment_count': 'comments'})
    
    #Changing object types to date types for two columns
    dfh['publishedAt']=pd.to_datetime(dfh['publishedAt'])
    dfh['trending_date']=pd.to_datetime(dfh['trending_date'])
    
    
    #Removing time stamp from date
    dfh['publishedAt']=dfh['publishedAt'].dt.date 
    dfh['trending_date']=dfh['trending_date'].dt.date
    
    
    with open(f'data/{country_code}_category_id.json', 'r') as read_file:
        category_ids = json.load(read_file)

        dfh=dfh.astype({'categoryId': 'str'})
        
    for index,row in dfh.iterrows():
    
        for entry in category_ids["items"]:

            if row["categoryId"]==entry["id"]:
                dfh.at[index,"categoryId"]=entry["snippet"]["title"]
    
    # Select 999 rows from each country in dataframe (so we end up with <10k rows ~1000 rows per country)
    dfh = dfh.nlargest(999, 'views')
    
    #Adding country Code as column
    dfh['country']=f'{country_code}'
    col_name='country'
    
    #Moving country code to first column
    first_col = dfh.pop(col_name)
    dfh.insert(0,col_name,first_col)
    
    return dfh

#USA Dataframe
dfh_us=import_func('US')

#Brasil Dataframe
dfh_br=import_func('BR')

#Canada Dataframe
dfh_ca=import_func('CA')

#Mexico Dataframe
dfh_mx=import_func('MX')

#GB Dataframe
dfh_gb=import_func('GB')

#France Dataframe
dfh_fr=import_func('FR')

#Russia Dataframe
dfh_ru=import_func('RU')

#Japan Dataframe
dfh_jp=import_func('JP')

#Korea Dataframe
dfh_kr=import_func('KR')

#India Dataframe
dfh_in=import_func('IN')


#Creating a varible to add all dfs
country_dfh=[dfh_us, dfh_br, dfh_ca, dfh_mx, dfh_gb, dfh_fr, dfh_ru ,dfh_jp, dfh_kr ,dfh_in]

dfh_main = pd.concat(country_dfh)
dfh_main

# Fix the 29 vs Non profits issue
dfh_main['categoryId'] = dfh_main['categoryId'].replace(["29"],"Nonprofits & Activism")


#View output
dfh_main
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'views'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-610b62009920> in <module>
#      53
#      54 #USA Dataframe
# ---> 55 dfh_us=import_func('US')
#      56
#      57 #Brasil Dataframe
#
# <ipython-input-31-610b62009920> in import_func(country_code)
#      40
#      41     # Select 999 rows from each country in dataframe (so we end up with <10k rows ~1000 rows per country)
# ---> 42     dfh = dfh.nlargest(999, 'views')
#      43
#      44     #Adding country Code as column
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in nlargest(self, n, columns, keep)
#    5194         Brunei      434000    12128      BN
#    5195         """
# -> 5196         return algorithms.SelectNFrame(self, n=n, keep=keep, columns=columns).nlargest()
#    5197
#    5198     def nsmallest(self, n, columns, keep="first"):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\algorithms.py in nlargest(self)
#    1121
#    1122     def nlargest(self):
# -> 1123         return self.compute("nlargest")
#    1124
#    1125     def nsmallest(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\algorithms.py in compute(self, method)
#    1239
#    1240         for column in columns:
# -> 1241             dtype = frame[column].dtype
#    1242             if not self.is_valid_dtype_n_method(dtype):
#    1243                 raise TypeError(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'views'

# %%
# dfh_main['categoryId'] = df_main['categoryId'].str.replace("29", "Nonprofits & Activism")
# dfh_main['categoryId'] = dfh_main['categoryId'].replace(["29"],"Nonprofits & Activism")


# df_main['categoryId'].value_counts()
# df_main['categoryId'].unique()
# dfh_main
# df_main = df_main(columns={})
# df_main['likes']

# df_main['publishedAt'].value_counts()

# %%
# Bar graph route
youtubeVids = df_main
country = "US"
metric = "likes"
youtubeVids['categoryId'] = youtubeVids['categoryId'].replace(["29"],"Nonprofits & Activism")
barGraph1Data = youtubeVids[youtubeVids["country"] == country]

barGraph1Data = barGraph1Data.groupby('categoryId').mean()
barGraph1Data = barGraph1Data[metric]
barGraph1Data
# Out:
# categoryId
# Autos & Vehicles          53588.263415
# Comedy                   115592.326196
# Education                 76952.064583
# Entertainment            153069.844634
# Film & Animation         107222.955610
# Gaming                   163714.600399
# Howto & Style             72941.372624
# Music                    357801.360620
# News & Politics           21329.559653
# Nonprofits & Activism     35196.440000
# People & Blogs           133745.807858
# Pets & Animals            45226.451389
# Science & Technology      84213.552558
# Sports                    35403.001547
# Travel & Events           24448.074468
# Name: likes, dtype: float64

# %%
# Bargraph2 route
youtubeVids = df_main
country = "US"
metric = "likes"
catId = "Entertainment"

barGraph2Data = youtubeVids[youtubeVids["country"] == country]
barGraph2Data = barGraph2Data[barGraph2Data["categoryId"] == catId]
barGraph2Data = barGraph2Data.loc[:, ["views", "comments", "likes", "dislikes", "country", "categoryId"]]

metric_values = ["views", "comments", "likes", "dislikes"]
metricMaxValues = []
n = 0
for i in metric_values:
    step1_df = barGraph2Data.sort_values(by=i, ascending=False)
    step2_df = step1_df[i]
    step3 = step2_df.values.tolist()
    metricMaxValues.append(step3[0])
metricMaxValues

barGraph2_df = pd.DataFrame(
    {'Metric Values': metric_values,
     'Max Value': metricMaxValues
    })
barGraph2_df
# Out:
#    Metric Values  Max Value
# 0     view_count   31801966
# 1  comment_count     681063
# 2          likes    2577092
# 3       dislikes      76584

# %%
# table by category route
youtubeVids = df_main
country = "US"
metric = "likes"
category = "Entertainment"

# # Fix the 29 vs Non profits issue
youtubeVids['categoryId'] = youtubeVids['categoryId'].replace(["29"],"Nonprofits & Activism")

# # Sort dataframe by country & category
table_df = youtubeVids[youtubeVids["country"] == country]
table_df = table_df[table_df["categoryId"] == category]

# # Sort dataframe (largest to smallest) by metric
sorted_table_df = table_df.sort_values(by=metric, ascending=False)

# # Removing duplicate titles from dataframe
sorted_table_df = sorted_table_df.drop_duplicates(subset='title', keep="first")
sorted_table_df

# # Select top 10 from dataframe
top10List_df = sorted_table_df.nlargest(10, metric)

# # Select columns to keep
top10List_df = top10List_df[['categoryId', 'title', 'channelTitle', 'view_count', 'comment_count', 'trending_date', 'likes', 'dislikes', 'video_id' ]]
top10List_df
# Out:
#           categoryId                                              title  \
# 5397   Entertainment              BTS Performs Dynamite | 2020 MTV VMAs
# 12196  Entertainment                                   Hi Me In 5 Years
# 2351   Entertainment             Last To Leave $800,000 Island Keeps It
# 9398   Entertainment          I Gave My 40,000,000th Subscriber 40 Cars
# 1781   Entertainment                          I Bought A Private Island
# 8765   Entertainment                       Why I Haven’t Been Uploading
# 17579  Entertainment                I Survived 24 Hours Straight In Ice
# 8373   Entertainment  BTS Performs Dynamite on AGT - America's Got T...
# 3373   Entertainment  Would YOU Rather Have A Lamborghini or This Ho...
# 386    Entertainment                               TREASURE - 'BOY' M/V
#
#                channelTitle  view_count  comment_count trending_date    likes  \
# 5397                    MTV    29442683         148096    2020-09-07  2577092
# 12196               MrBeast    21701884         175728    2020-10-11  2494869
# 2351                MrBeast    31801966         201630    2020-08-23  2097381
# 9398                MrBeast    28567218         151635    2020-09-27  1815713
# 1781                MrBeast    30234876         121292    2020-08-20  1801095
# 8765                MrBeast    20869977          97467    2020-09-24  1748970
# 17579               MrBeast    25739361         163122    2020-11-08  1641951
# 8373   America's Got Talent    14032448          89597    2020-09-22  1599023
# 3373                MrBeast    20807368         126774    2020-08-28  1486530
# 386          TREASURE (트레저)    19682753         346975    2020-08-13  1473055
#
#        dislikes     video_id
# 5397      58524  zJCdkOpU90g
# 12196     10347  AKJfakEsgy0
# 2351      35643  NkE0AMGzpJY
# 9398      23359  UE5AHE2Ypr8
# 1781      23693  FbM1yi4mMMc
# 8765      15767  TDiXxsQ0w2Q
# 17579     19460  SZQhgExjBvQ
# 8373      21726  MH_vjfNPv70
# 3373      13908  s1ax8Tx_Jz0
# 386       25964  JSAfPh1A25E

# %%
# Out:
# Custom Lamborghini Vs Tesla Race - Winner Keeps Car                                                    1
# Custom Lamborghini vs. Tesla - Winner Keeps Car                                                        1
# BREAKING: President Trump and First Lady test positive for COVID-19                                    1
# [최초공개] ENHYPEN - ♬Let Me In (20 CUBE) l ENHYPEN DEBUT SHOW : DAY ONE                                   1
# good news, all is okay now, should be back to normal soon                                              1
# I FOUGHT BRYCE HALL...Ft. Mike Majlak, Lana Rhoades, Steve will do it, Nelk Boys, Blake Gray           1
# I'm Pregnant!!                                                                                         1
# MAKING COUPLES SWITCH PHONES Loyalty Test Pt. 2 💔 ATLANTA MALL EDITION | Public Interview              1
# Tamara Jade Performs Lizzo's Cuz I Love You and Gets a Four-Chair Turn - The Voice Blind Auditions     1
# The Mad Butcher, Cleveland Torso Killer - Still Unsolved ?? Mystery and Makeup | Bailey Sarian         1
# Brooklyn's 10 DATES in 10 DAYS | Meet Jorge (Date #1)                                                  1
# BTS Sings 'Santa Claus Is Comin' To Town' - The Disney Holiday Singalong                               1
# Verizon Live: Macy's Thanksgiving Day Parade 2020                                                      1
# Nas - Ultra Black (Official Video)                                                                     1
# Son, lemme teach you something new                                                                     1
# Raised by Wolves | New Trailer | HBO Max                                                               1
# Billie Eilish: Same Interview, The Fourth Year | Vanity Fair                                           1
# I Uber’d People And Gave Them A Lamborghini                                                            1
# Custom Lamborghini VS Tesla, Winner Keeps Car                                                          1
# Get Him 1,000,000 Subscribers in 24 Hours                                                              1
# King Von & Lil Durk “Back Again” feat. Prince Dre (Official Music Video)                               1
# Introducing My Son Dante For The First Time EVER! | Creator Spotlights                                 1
# I Exercised For 24 Hours Straight - This is What Happened...                                           1
# Jazmine Sullivan Performs ‘Lost Ones’ & ‘Pick Up Your Feelings’ | Soul Train Awards 20                 1
# Justin Bieber Performs Lonely & Holy at 2020 People's Choice Awards | E! People’s Choice Awards        1
# Forgive Me - Live - Chloe x Halle                                                                      1
# aespa(에스파) - Black Mamba [Music Bank / 2020.11.20]                                                     1
# How I Gave Away $1,000,000 Custom iPhones, iPads, Lamborghinis And More! | ZHC                         1
# Normal School Vs. Online School                                                                        1
# Trixie Bakes A Chocolate Cake In The OG 1963 Easy Bake Oven *FAIL* (One Million Subscribers Video!)    1
# Floyd Mayweather & KSI React To Jake Paul & Nate Robinson Fight                                        1
# BTS BE Interview                                                                                       1
# King Von & Lil Durk “We Back Again” feat. Prince Dre (Official Music Video)                            1
# Jaden Smith Goes Sneaker Shopping With Complex                                                         1
# Strongest Punch Wins $1,000 (ft. World's Strongest Kid)                                                1
# Push This Red Button For $100,000                                                                      1
# JUDAS AND THE BLACK MESSIAH - Official Trailer                                                         1
# Irish People Try Celebrity Alcohol (Ryan Reynolds, Aviation Gin)                                       1
# Cake Rescue Fixing Viral Cake Fails | How To Cook That Ann Reardon new 2020                            1
# Name: title, dtype: int64

# %%
# Out:
# 4100 4100

# %%
# Out:
# 3276

# %%
# Out:
#       country     video_id                                              title  \
# 207        US  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 217        US  w-aidBdvZo8  I Haven't Been Honest About My Injury.. Here's...
# 229        US  SnsPZj91R7E  SURPRISING MY DAD WITH HIS DREAM TRUCK!! | Lou...
# 235        US  6TIsR_7nrNc  Kylie Jenner Reacts To 'WAP' Music Video Backlash
# 243        US  p7HGUZWq_8s                          Doing Doja Cat’s Makeup!!
# ...       ...          ...                                                ...
# 21970      US  tOsZAW-eIS4  Raising Cane's Full Menu Challenge!! (All 5 Co...
# 21972      US  7jmjr1ctP8w       Insane UMAMI Dry Age Experiment | Guga Foods
# 21973      US  FFg-d4vwE9k                           LOGAN AND JOSIE BROKE UP
# 21979      US  73qR9pdlsAo                   Canadian Winter Water Gun FIGHT!
# 21993      US  kAvu5pRfb7Q  When Barack Obama First Asked Michelle About R...
#
#       publishedAt                        channelTitle     categoryId  \
# 207    2020-08-11                       jacksepticeye  Entertainment
# 217    2020-08-11                      Professor Live  Entertainment
# 229    2020-08-10                        Louie's Life  Entertainment
# 235    2020-08-10                       HollywoodLife  Entertainment
# 243    2020-08-11                       James Charles  Entertainment
# ...           ...                                 ...            ...
# 21970  2020-11-25                         Matt Stonie  Entertainment
# 21972  2020-11-25                          Guga Foods  Entertainment
# 21973  2020-11-25                    Impaulsive Clips  Entertainment
# 21979  2020-11-25                   Channel Super Fun  Entertainment
# 21993  2020-11-25  The Late Show with Stephen Colbert  Entertainment
#
#       trending_date  view_count   likes  dislikes  comment_count  \
# 207      2020-08-13     2802823  401421      3728          44546
# 217      2020-08-13     1300729   89062      1128           8584
# 229      2020-08-13     1642191  107664      2476           7180
# 235      2020-08-13     1377584   12937     11356           3500
# 243      2020-08-13     4819411  461786      7191          30613
# ...             ...         ...     ...       ...            ...
# 21970    2020-12-01     4950605  317049      4266          17144
# 21972    2020-12-01     1201402   35622       959           5617
# 21973    2020-12-01     1232353   47394       884           2619
# 21979    2020-12-01      376575   23045       415           1796
# 21993    2020-12-01     2424724   41322      1458           3914
#
#                                        thumbnail_link
# 207    https://i.ytimg.com/vi/J78aPJ3VyNs/default.jpg
# 217    https://i.ytimg.com/vi/w-aidBdvZo8/default.jpg
# 229    https://i.ytimg.com/vi/SnsPZj91R7E/default.jpg
# 235    https://i.ytimg.com/vi/6TIsR_7nrNc/default.jpg
# 243    https://i.ytimg.com/vi/p7HGUZWq_8s/default.jpg
# ...                                               ...
# 21970  https://i.ytimg.com/vi/tOsZAW-eIS4/default.jpg
# 21972  https://i.ytimg.com/vi/7jmjr1ctP8w/default.jpg
# 21973  https://i.ytimg.com/vi/FFg-d4vwE9k/default.jpg
# 21979  https://i.ytimg.com/vi/73qR9pdlsAo/default.jpg
# 21993  https://i.ytimg.com/vi/kAvu5pRfb7Q/default.jpg
#
# [3276 rows x 12 columns]

# %%
# Out:
#       country     video_id                                              title  \
# 2          US  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 5          US  w-aidBdvZo8  I Haven't Been Honest About My Injury.. Here's...
# 8          US  SnsPZj91R7E  SURPRISING MY DAD WITH HIS DREAM TRUCK!! | Lou...
# 16         US  6TIsR_7nrNc  Kylie Jenner Reacts To 'WAP' Music Video Backlash
# 22         US  FopIxceEr8g    EXTREME Game of Hide and Seek in my NEW HOUSE!!
# ...       ...          ...                                                ...
# 21970      US  tOsZAW-eIS4                                                NaN
# 21972      US  7jmjr1ctP8w                                                NaN
# 21973      US  FFg-d4vwE9k                                                NaN
# 21979      US  73qR9pdlsAo                                                NaN
# 21993      US  kAvu5pRfb7Q                                                NaN
#
#       publishedAt                        channelTitle     categoryId  \
# 2      2020-08-11                       jacksepticeye  Entertainment
# 5      2020-08-11                      Professor Live  Entertainment
# 8      2020-08-10                        Louie's Life  Entertainment
# 16     2020-08-10                       HollywoodLife  Entertainment
# 22     2020-08-10                            FaZe Rug  Entertainment
# ...           ...                                 ...            ...
# 21970  2020-11-25                         Matt Stonie  Entertainment
# 21972  2020-11-25                          Guga Foods  Entertainment
# 21973  2020-11-25                    Impaulsive Clips  Entertainment
# 21979  2020-11-25                   Channel Super Fun  Entertainment
# 21993  2020-11-25  The Late Show with Stephen Colbert  Entertainment
#
#       trending_date  view_count   likes  dislikes  comment_count  \
# 2        2020-08-12     2038853  353787      2628          40221
# 5        2020-08-12      949491   77487       746           7506
# 8        2020-08-12     1402687   95694      2158           6613
# 16       2020-08-12     1007540   10102      7932           2763
# 22       2020-08-12     3061467  206840      2646          14934
# ...             ...         ...     ...       ...            ...
# 21970    2020-12-01     4950605  317049      4266          17144
# 21972    2020-12-01     1201402   35622       959           5617
# 21973    2020-12-01     1232353   47394       884           2619
# 21979    2020-12-01      376575   23045       415           1796
# 21993    2020-12-01     2424724   41322      1458           3914
#
#                                        thumbnail_link
# 2      https://i.ytimg.com/vi/J78aPJ3VyNs/default.jpg
# 5      https://i.ytimg.com/vi/w-aidBdvZo8/default.jpg
# 8      https://i.ytimg.com/vi/SnsPZj91R7E/default.jpg
# 16     https://i.ytimg.com/vi/6TIsR_7nrNc/default.jpg
# 22     https://i.ytimg.com/vi/FopIxceEr8g/default.jpg
# ...                                               ...
# 21970  https://i.ytimg.com/vi/tOsZAW-eIS4/default.jpg
# 21972  https://i.ytimg.com/vi/7jmjr1ctP8w/default.jpg
# 21973  https://i.ytimg.com/vi/FFg-d4vwE9k/default.jpg
# 21979  https://i.ytimg.com/vi/73qR9pdlsAo/default.jpg
# 21993  https://i.ytimg.com/vi/kAvu5pRfb7Q/default.jpg
#
# [4100 rows x 12 columns]

# %%
# Out:
#       country     video_id                                              title  \
# 2          US  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 5          US  w-aidBdvZo8  I Haven't Been Honest About My Injury.. Here's...
# 8          US  SnsPZj91R7E  SURPRISING MY DAD WITH HIS DREAM TRUCK!! | Lou...
# 16         US  6TIsR_7nrNc  Kylie Jenner Reacts To 'WAP' Music Video Backlash
# 22         US  FopIxceEr8g    EXTREME Game of Hide and Seek in my NEW HOUSE!!
# ...       ...          ...                                                ...
# 21827      US  2tdjeCKdIv4                    Normal School Vs. Online School
# 21848      US  FbQSWzKEJ64  Introducing My Son Dante For The First Time EV...
# 21850      US  pkaCzwner3M  Trixie Bakes A Chocolate Cake In The OG 1963 E...
# 21857      US  PGFicrydZG0  [최초공개] ENHYPEN - ♬Let Me In (20 CUBE) l ENHYPE...
# 21868      US  jVJOYWqX3G0                                   BTS BE Interview
#
#       publishedAt    channelTitle     categoryId trending_date  view_count  \
# 2      2020-08-11   jacksepticeye  Entertainment    2020-08-12     2038853
# 5      2020-08-11  Professor Live  Entertainment    2020-08-12      949491
# 8      2020-08-10    Louie's Life  Entertainment    2020-08-12     1402687
# 16     2020-08-10   HollywoodLife  Entertainment    2020-08-12     1007540
# 22     2020-08-10        FaZe Rug  Entertainment    2020-08-12     3061467
# ...           ...             ...            ...           ...         ...
# 21827  2020-12-01        youtwoTV  Entertainment    2020-12-01      215719
# 21848  2020-11-30           Yammy  Entertainment    2020-12-01      186844
# 21850  2020-11-30   Trixie Mattel  Entertainment    2020-12-01      336893
# 21857  2020-11-30      Mnet K-POP  Entertainment    2020-12-01     1832963
# 21868  2020-11-29  Zach Sang Show  Entertainment    2020-12-01      573386
#
#         likes  dislikes  comment_count  \
# 2      353787      2628          40221
# 5       77487       746           7506
# 8       95694      2158           6613
# 16      10102      7932           2763
# 22     206840      2646          14934
# ...       ...       ...            ...
# 21827   17691       214           1028
# 21848   23660       225           5294
# 21850   42723       132           3127
# 21857  257214      1918          14017
# 21868   81808       204           4373
#
#                                        thumbnail_link
# 2      https://i.ytimg.com/vi/J78aPJ3VyNs/default.jpg
# 5      https://i.ytimg.com/vi/w-aidBdvZo8/default.jpg
# 8      https://i.ytimg.com/vi/SnsPZj91R7E/default.jpg
# 16     https://i.ytimg.com/vi/6TIsR_7nrNc/default.jpg
# 22     https://i.ytimg.com/vi/FopIxceEr8g/default.jpg
# ...                                               ...
# 21827  https://i.ytimg.com/vi/2tdjeCKdIv4/default.jpg
# 21848  https://i.ytimg.com/vi/FbQSWzKEJ64/default.jpg
# 21850  https://i.ytimg.com/vi/pkaCzwner3M/default.jpg
# 21857  https://i.ytimg.com/vi/PGFicrydZG0/default.jpg
# 21868  https://i.ytimg.com/vi/jVJOYWqX3G0/default.jpg
#
# [824 rows x 12 columns]
